# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Conda install seaborn
# pip install seaborn

# %%
df = pd.read_csv('titanic.csv', index_col = 0)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
c = df.corr()        #Correlation Matrix
c
# Out:
# C:\Users\Preeti Pratima\AppData\Local\Temp\ipykernel_15876\2972276254.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c = df.corr()        #Correlation Matrix
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
df.corr().unstack()
# Out:
# C:\Users\Preeti Pratima\AppData\Local\Temp\ipykernel_15876\4102424629.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().unstack()
# Survived  Survived    1.000000
#           Pclass     -0.338481
#           Age        -0.077221
#           SibSp      -0.035322
#           Parch       0.081629
#           Fare        0.257307
# Pclass    Survived   -0.338481
#           Pclass      1.000000
#           Age        -0.369226
#           SibSp       0.083081
#           Parch       0.018443
#           Fare       -0.549500
# Age       Survived   -0.077221
#           Pclass     -0.369226
#           Age         1.000000
#           SibSp      -0.308247
#           Parch      -0.189119
#           Fare        0.096067
# SibSp     Survived   -0.035322
#           Pclass      0.083081
# ...

# %%
df.corr?

# %%
sns.heatmap(c, annot = True, cmap = 'coolwarm', linewidth = 0)
plt.show()

# %%
sns.heatmap(c, annot = False, cmap = 'viridis', linewidth = 2)
plt.show()

# %%
sns.heatmap?

# %%
sns.distplot(df['Age'], bins = 8, kde = False)         #Distribution Plot
# Out:
# C:\Users\Preeti Pratima\AppData\Local\Temp\ipykernel_15876\1331851202.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins = 8, kde = False)         #Distribution Plot
# <Axes: xlabel='Age'>

# %%
sns.distplot(df['Age'], bins = 16, kde = False)             #Distribution plot
# Out:
# C:\Users\Preeti Pratima\AppData\Local\Temp\ipykernel_15876\44553185.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins = 16, kde = False)             #Distribution plot
# <Axes: xlabel='Age'>

# %%
sns.distplot(df['Age'], bins = 8, kde = True)    # Distribution Plot  # kernel density estimation
# Out:
# C:\Users\Preeti Pratima\AppData\Local\Temp\ipykernel_15876\3043877039.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins = 8, kde = True)    # Distribution Plot  # kernel density estimation
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'], bins = 40, kde = False)    # Distribution Plot
# Out:
# C:\Users\Preeti Pratima\AppData\Local\Temp\ipykernel_15876\3750728926.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins = 40, kde = False)    # Distribution Plot
# <Axes: xlabel='Age'>

# %%
sns.displot(df['Age'], bins = 8, kde = True)    # Distribution Plot

# %%
sns.displot?

# %%
sns.distplot(df['Age'], bins = 8, kde = True, vertical = True)    # Distribution Plot
# Out:
# C:\Users\Preeti Pratima\AppData\Local\Temp\ipykernel_15876\19452859.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins = 8, kde = True, vertical = True)    # Distribution Plot
# <Axes: xlabel='Density', ylabel='Age'>

# %%
sns.distplot(df['Age'], bins = 8, kde = False, vertical = True)    # Distribution Plot
# Out:
# C:\Users\Preeti Pratima\AppData\Local\Temp\ipykernel_15876\670422794.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins = 8, kde = False, vertical = True)    # Distribution Plot
# <Axes: ylabel='Age'>

# %%
sns.countplot(x = 'Pclass', data = df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# sns.countplot(df['Pclass'], palette = ['red', 'blue', 'green'])
sns.countplot(x = 'Pclass', data = df, palette = list('rbg'))
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df['Pclass'], hue = df['Embarked'], dodge = True, palette = ['y', 'r', 'b'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sns.countplot(df['Pclass'], hue = df['Embarked'], dodge = True, palette = ['y', 'r', 'b'])
#
# File C:\Python 3.11\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
sns.countplot(df['Pclass'], hue = df['Embarked'], dodge = False, palette = ['y', 'r', 'b'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sns.countplot(df['Pclass'], hue = df['Embarked'], dodge = False, palette = ['y', 'r', 'b'])
#
# File C:\Python 3.11\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...
